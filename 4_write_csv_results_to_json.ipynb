# %%
import os, sys, csv, json, re
import numpy as np
import pandas as pd

# %% [markdown]
# ## Calculate area from 3D vertice

# %%
#determinant of matrix a
def det(a):
    return a[0][0]*a[1][1]*a[2][2] + a[0][1]*a[1][2]*a[2][0] + a[0][2]*a[1][0]*a[2][1] - a[0][2]*a[1][1]*a[2][0] - a[0][1]*a[1][0]*a[2][2] - a[0][0]*a[1][2]*a[2][1]

#unit normal vector of plane defined by points a, b, and c
def unit_normal(a, b, c):
    x = det([[1,a[1],a[2]],
             [1,b[1],b[2]],
             [1,c[1],c[2]]])
    y = det([[a[0],1,a[2]],
             [b[0],1,b[2]],
             [c[0],1,c[2]]])
    z = det([[a[0],a[1],1],
             [b[0],b[1],1],
             [c[0],c[1],1]])
    magnitude = (x**2 + y**2 + z**2)**.5
    return (x/magnitude, y/magnitude, z/magnitude)

#dot product of vectors a and b
def dot(a, b):
    return a[0]*b[0] + a[1]*b[1] + a[2]*b[2]

#cross product of vectors a and b
def cross(a, b):
    x = a[1] * b[2] - a[2] * b[1]
    y = a[2] * b[0] - a[0] * b[2]
    z = a[0] * b[1] - a[1] * b[0]
    return (x, y, z)

#area of polygon poly
def area(poly):
    if len(poly) < 3: # not a plane - no area
        return 0

    total = [0, 0, 0]
    for i in range(len(poly)):
        vi1 = poly[i]
        if i is len(poly)-1:
            vi2 = poly[0]
        else:
            vi2 = poly[i+1]
        prod = cross(vi1, vi2)
        total[0] += prod[0]
        total[1] += prod[1]
        total[2] += prod[2]
    result = dot(total, unit_normal(poly[0], poly[1], poly[2]))
    return abs(result/2)

# %% [markdown]
# ## Read red nodes

# %%
name_to_id = {}
work_folder = 'SF_100'
scene_folder = 'scene-json'
res_json = {}
with open(os.path.join(scene_folder, 'meta', 'sf_dt_98_red_nodes_data_exchanges.json'), 'r') as f:
    eplus_meta = json.load(f)
    for bldg in eplus_meta['features']:
        bldg_id = bldg['id']
        res_json[bldg_id] = {}
        name_to_id[bldg_id] = {}
        total_area = 0
        for surf in bldg['properties']['objects']:
            surf_id = surf['id']
            res_json[bldg_id][surf_id] = {}
            name_to_id[bldg_id][surf['properties']['name']] = surf_id
            res_json[bldg_id][surf_id]['name'] = surf['properties']['name']
            res_json[bldg_id][surf_id]['v'] = surf['properties']['v']
            res_json[bldg_id][surf_id]['area'] = area(surf['properties']['v'])
            total_area += res_json[bldg_id][surf_id]['area']
        for surf in bldg['properties']['objects']:
            surf_id = surf['id']
            res_json[bldg_id][surf_id]['area_to_zone'] = res_json[bldg_id][surf_id]['area'] / total_area

# %%
res_json['bldg_3981169_2289']['surf_1']
# Out:
# {'name': 'S1-office-core-wall-0',
#  'v': [[377.9300000001956, 529.8599999999627, 5.22],
#   [377.9300000001956, 529.8599999999627, 0.0],
#   [375.0800000001024, 549.5999999999534, 0.0],
#   [375.0800000001024, 549.5999999999534, 5.22]],
#  'area': 104.11120862253202,
#  'area_to_zone': 0.022220621277582762}

# %% [markdown]
# ## Read EnergyPlus output CSV files

# %%
# example file
result_name = os.path.join(work_folder, 'bldg_3981169_2289', 'eplusout-r2.csv') ## TODO
df_eplus_result = pd.read_csv(result_name, sep=',', parse_dates=True, infer_datetime_format=True, encoding='UTF-8')

# %%
df_eplus_result.keys()
# Out:
# Index(['Date/Time',
#        'Environment:Site Outdoor Air Drybulb Temperature [C](Hourly)',
#        'Environment:Site Outdoor Air Dewpoint Temperature [C](Hourly)',
#        'Environment:Site Outdoor Air Wetbulb Temperature [C](Hourly)',
#        'Environment:Site Outdoor Air Relative Humidity [%](Hourly)',
#        'Environment:Site Outdoor Air Barometric Pressure [Pa](Hourly)',
#        'Environment:Site Wind Speed [m/s](Hourly)',
#        'Environment:Site Wind Direction [deg](Hourly)',
#        'S1 OFFICE CORE WALL 0:Surface Outside Face Temperature [C](Hourly)',
#        'S1 OFFICE CORE WALL 0:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Hourly)',
#        ...
#        'SUB SURFACE 45:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Hourly)',
#        'SUB SURFACE 45:Surface Outside Face Heat Emission to Air Rate [W](Hourly)',
#        'SUB SURFACE 46:Surface Outside Face Temperature [C](Hourly)',
#        'SUB SURFACE 46:Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Hourly)',
#        'SUB SURFACE 46:Surface Outside Face Heat Emission to Air Rate [W](Hourly)',
#        'Environment:Site Total Zone Exfiltration Heat Loss [J](Hourly)',
#        'SimHVAC:Air System Relief Air Total Heat Loss Energy [J](Hourly)',
#        'SimHVAC:HVAC System Total Heat Rejection Energy [J](Hourly)',
#        'Cooling:Electricity [J](Hourly)', 'Electricity:Facility [J](Hourly)'],
#       dtype='object', length=304)

# %%
time_stamps = set()
for bldg in res_json:
    result_name_1 = os.path.join(work_folder, bldg, 'eplusout-r2.csv')  ## TODo
    df_eplus_result = pd.read_csv(result_name_1, sep=',', parse_dates=True, infer_datetime_format=True, encoding='UTF-8')
    for col in df_eplus_result:
        df_eplus_result[col.strip()] = df_eplus_result[col]
    
    if not 'SimHVAC:HVAC System Total Heat Rejection Energy [J](Hourly)' in df_eplus_result:
        print(bldg + " not enough")
        continue
    for surf in res_json[bldg]:
        surf_name = res_json[bldg][surf]['name'].upper().replace('-', ' ')
        for index, row in df_eplus_result.iterrows():
            eplus_header_temp = surf_name + ':Surface Outside Face Temperature [C](Hourly)'
            eplus_header_h = surf_name + ':Surface Outside Face Convection Heat Transfer Coefficient [W/m2-K](Hourly)'

            eplus_header_emission_exf = 'Environment:Site Total Zone Exfiltration Heat Loss [J](Hourly)'
            surf_to_zone_rate = res_json[bldg][surf]['area_to_zone']
            
            eplus_header_conv_emission = surf_name + ':Surface Outside Face Heat Emission to Air Rate [W](Hourly)'
            exf_emission = row[eplus_header_emission_exf] * 0.000277778 * surf_to_zone_rate
            
            rel_emission = 0
            rej_emission = 0
            if 'ROOF' in surf_name:
                eplus_header_emission_rej = 'SimHVAC:HVAC System Total Heat Rejection Energy [J](Hourly)'
                eplus_header_emission_rel = 'SimHVAC:Air System Relief Air Total Heat Loss Energy [J](Hourly)'
                rel_emission = row[eplus_header_emission_rel] * 0.000277778
                rej_emission = row[eplus_header_emission_rej] * 0.000277778

                                
            surf_emission_hvac = exf_emission + rel_emission + rej_emission
            surf_emission_total = row[eplus_header_conv_emission] + surf_emission_hvac

            res_json[bldg][surf][row['Date/Time']] = [row[eplus_header_temp], 
                                                      row[eplus_header_h],
                                                      surf_emission_hvac,
                                                      surf_emission_hvac / res_json[bldg][surf]['area'],
                                                      surf_emission_total,
                                                      surf_emission_total / res_json[bldg][surf]['area']
                                                     ]
            time_stamps.add(row['Date/Time'])

# %%
### Merging "old" surface to "new" ("new" surfaces represent heat from old surfaces)

# %%
base_to_old = {}
with open(os.path.join(scene_folder, 'meta', 'Merged_surfaces.txt'), 'r') as txt_file:
    lines = txt_file.readlines()
for i in range(1, len(lines)):
    old, new = lines[i].strip().split('		')[0].strip(), lines[i].strip().split('		')[1].strip()
    if new not in base_to_old:
        base_to_old[new] = [new, old]
    else:
        base_to_old[new].append(old)

for new_surf in base_to_old['bldg_3981169_2289 :  S1-office-core-wall-0']:
    print(new_surf)
# Out:
# bldg_3981169_2289 :  S1-office-core-wall-0
# bldg_3981169_2289 : S1-office-core-wall-1
# bldg_3981169_2289 : S1-office-core-wall-10
# bldg_3981169_2289 : S1-office-core-wall-11
# bldg_3981169_2289 : S1-office-core-wall-2
# bldg_3981169_2289 : S1-office-core-wall-3
# bldg_3981169_2289 : S2-office-core-wall-1
# bldg_3981169_2289 : S2-office-core-wall-10
# bldg_3981169_2289 : S2-office-core-wall-11
# bldg_3981169_2289 : S2-office-core-wall-2
# bldg_3981169_2289 : S2-office-core-wall-3
# bldg_3981169_2289 : S3-office-core-wall-10
# bldg_3981169_2289 : S3-office-core-wall-11
# bldg_3981169_2289 : S3-office-core-wall-2
# bldg_3981169_2289 : S4-office-core-wall-10
# bldg_3981169_2289 : S4-office-core-wall-11

# %%
name_to_id['bldg_3981169_2289']['S1-office-core-wall-0']
# Out:
# 'surf_1'

# %%
## Before merging the heat and temperatures
# [temperature, conv_coeff, surf_emission_hvac, surf_emission_hvac_flux, surf_emission_total, surf_emission_total_flux]
print(res_json['bldg_3981169_2289']['surf_1'][' 09/01  01:00:00'])
# Out:
# [25.05723901009709, 1.778531810456938, 53.33446209028229, 0.5122835744194743, 61.93245767894831, 0.5948682999492595]

# %%
for time in time_stamps:
    for base in base_to_old:
        total_temp, total_conv_coeff, total_q_hvac, total_heat_hvac, total_q, total_heat = 0, 0, 0, 0, 0, 0
        base_bldg = base.split(' : ')[0].strip()
        if base.split(' : ')[1].strip() not in name_to_id[base_bldg]:
            print(base_bldg, base.split(' : ')[1].strip())
            continue
        base_surf = name_to_id[base_bldg][base.split(' : ')[1].strip()]
        total_area = 0
        for old in base_to_old[base]:
            bldg = old.split(' : ')[0].strip()
            surf = name_to_id[bldg][old.split(' : ')[1].strip()]
            curr_area = res_json[bldg][surf]['area']
            total_area += curr_area
            total_temp += res_json[bldg][surf][time][0] * curr_area
            total_conv_coeff += res_json[bldg][surf][time][1] * curr_area
            total_q_hvac += res_json[bldg][surf][time][2] * curr_area
            total_heat_hvac += res_json[bldg][surf][time][3]
            total_q += res_json[bldg][surf][time][4] * curr_area
            total_heat += res_json[bldg][surf][time][5]
        res_json[base_bldg][base_surf][time][0] = total_temp / total_area
        res_json[base_bldg][base_surf][time][1] = total_conv_coeff / total_area
        res_json[base_bldg][base_surf][time][2] = total_q_hvac / total_area
        res_json[base_bldg][base_surf][time][3] = total_heat_hvac
        res_json[base_bldg][base_surf][time][4] = total_q / total_area
        res_json[base_bldg][base_surf][time][5] = total_heat

# %%
## After merging the heat and temperatures
print(res_json['bldg_3981169_2289']['surf_1'][' 09/01  01:00:00'])
# Out:
# [25.657370101904363, 1.6817763869511473, 105.29316109133748, 8.196537190711584, 484.4221199869833, 51.81562176907448]

# %%
for time in time_stamps:
    result_json = {}
    result_json['features'] = []
    time_stamp_to_write = time.replace('/', '_').replace('  ', '_').replace(':', '_')[:-3]
    for bldg in res_json:
        result_json_bldg = {}
        result_json_bldg['id'] = bldg
        result_json_bldg['properties'] = {}
        result_json_bldg['properties']['objects'] = []
        for surf in res_json[bldg]:
            result_json_surf = {}
            result_json_surf['id'] = surf
            result_json_surf['properties'] = {}
            result_json_surf['properties']['name'] = res_json[bldg][surf]['name']
            result_json_surf['properties']['temperature'] = res_json[bldg][surf][time][0]
            result_json_surf['properties']['conv_coeff'] = res_json[bldg][surf][time][1]
            result_json_surf['properties']['q_hvac'] = res_json[bldg][surf][time][2]
            result_json_surf['properties']['heat_flux_hvac'] = res_json[bldg][surf][time][3]
            result_json_surf['properties']['q_total'] = res_json[bldg][surf][time][4]
            result_json_surf['properties']['heat_flux_total'] = res_json[bldg][surf][time][5]
            result_json_bldg['properties']['objects'].append(result_json_surf)
        result_json['features'].append(result_json_bldg)
    ## TODO
    file = open(os.path.join(scene_folder, '2-eplus', 'sf_100_dt_hvac_eplus_2_' + time_stamp_to_write.strip() + '.json'), 'w')
    file.write(json.dumps(result_json, indent=2))
    file.close()

# %%
result_json
# Out:
# {'features': [{'id': 'bldg_3981169_2289',
#    'properties': {'objects': [{'id': 'surf_1',
#       'properties': {'name': 'S1-office-core-wall-0',
#        'temperature': 26.286032462896248,
#        'conv_coeff': 2.662666964658598,
#        'q_hvac': -3.8204831765511393,
#        'heat_flux_hvac': -0.2974051886990563,
#        'q_total': -4328.38012896251,
#        'heat_flux_total': -180.3296046378921}},
#      {'id': 'surf_2',
#       'properties': {'name': 'S1-office-core-wall-1',
#        'temperature': 24.857095402779773,
#        'conv_coeff': 2.1550884556860708,
#        'q_hvac': -0.5181573221692318,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -189.88077682704022,
#        'heat_flux_total': -6.811580895228273}},
#      {'id': 'surf_3',
#       'properties': {'name': 'S1-office-core-wall-10',
#        'temperature': 25.07792728822893,
#        'conv_coeff': 2.493938089079351,
#        'q_hvac': -1.9580621034433956,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -1315.728069887053,
#        'heat_flux_total': -12.490166751263493}},
#      {'id': 'surf_4',
#       'properties': {'name': 'S1-office-core-wall-11',
#        'temperature': 26.50188366816029,
#        'conv_coeff': 2.8549018030500246,
#        'q_hvac': -5.13213152611064,
#        'heat_flux_hvac': -0.018587824293691015,
#        'q_total': -6128.315222725467,
#        'heat_flux_total': -22.19585487956124}},
#      {'id': 'surf_5',
#       'properties': {'name': 'S1-office-core-wall-2',
#        'temperature': 28.303077392147678,
#        'conv_coeff': 1.432053245286195,
#        'q_hvac': -0.27452362797183993,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -16.00392549782216,
#        'heat_flux_total': -1.0836158525245578}},
#      {'id': 'surf_6',
#       'properties': {'name': 'S1-office-core-wall-3',
#        'temperature': 26.51286899344707,
#        'conv_coeff': 1.8761754665391728,
#        'q_hvac': -0.33706318028838445,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -61.47880245356156,
#        'heat_flux_total': -3.390335238680246}},
#      {'id': 'surf_7',
#       'properties': {'name': 'S1-office-core-wall-4',
#        'temperature': 23.838292097515232,
#        'conv_coeff': 2.326387693313066,
#        'q_hvac': -1.7343478150436082,
#        'heat_flux_hvac': -0.055763472881073056,
#        'q_total': -1095.1269124492655,
#        'heat_flux_total': -23.687192899888615}},
#      {'id': 'surf_8',
#       'properties': {'name': 'S1-office-core-wall-5',
#        'temperature': 23.344171217018143,
#        'conv_coeff': 2.3918870392383376,
#        'q_hvac': -1.8564462384820395,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -1211.0488865082589,
#        'heat_flux_total': -12.125728958298328}},
#      {'id': 'surf_9',
#       'properties': {'name': 'S1-office-core-wall-6',
#        'temperature': 24.8460969688904,
#        'conv_coeff': 1.7226105260639948,
#        'q_hvac': -0.24722484005154854,
#        'heat_flux_hvac': -0.0929391214684551,
#        'q_total': -42.74352260795949,
#        'heat_flux_total': -14.627489232377007}},
#      {'id': 'surf_10',
#       'properties': {'name': 'S1-office-core-wall-7',
#        'temperature': 25.469488769932443,
#        'conv_coeff': 1.2733463026953684,
#        'q_hvac': -0.1822818172385934,
#        'heat_flux_hvac': -0.018587824293691015,
#        'q_total': -6.941699824278986,
#        'heat_flux_total': -0.7078659769139313}},
#      {'id': 'surf_11',
#       'properties': {'name': 'S1-office-core-wall-8',
#        'temperature': 24.77028255180839,
#        'conv_coeff': 1.551888971387407,
#        'q_hvac': -0.25347461997888104,
#        'heat_flux_hvac': -0.018587824293691022,
#        'q_total': -24.39432536537529,
#        'heat_flux_total': -1.7888869256121396}},
#      {'id': 'surf_12',
#       'properties': {'name': 'S1-office-core-wall-9',
#        'temperature': 23.68613692596252,
#        'conv_coeff': 2.262360849962735,
#        'q_hvac': -3.294779189787492,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -1710.0870708611903,
#        'heat_flux_total': -9.64762618952038}},
#      {'id': 'surf_13',
#       'properties': {'name': 'S2-office-core-wall-0',
#        'temperature': 29.17116938480773,
#        'conv_coeff': 1.7310961943603709,
#        'q_hvac': -1.9352008528794344,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -142.64220012603275,
#        'heat_flux_total': -1.3700945557475908}},
#      {'id': 'surf_14',
#       'properties': {'name': 'S2-office-core-wall-1',
#        'temperature': 24.891029320874896,
#        'conv_coeff': 2.1283407871811573,
#        'q_hvac': -0.5181573221692319,
#        'heat_flux_hvac': -0.018587824293691022,
#        'q_total': -181.32982670743104,
#        'heat_flux_total': -6.5048332115286485}},
#      {'id': 'surf_15',
#       'properties': {'name': 'S2-office-core-wall-10',
#        'temperature': 25.152553909181925,
#        'conv_coeff': 2.52906176880413,
#        'q_hvac': -1.9580621034433956,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -1412.7780451384458,
#        'heat_flux_total': -13.411459229427274}},
#      {'id': 'surf_16',
#       'properties': {'name': 'S2-office-core-wall-11',
#        'temperature': 26.47954642006003,
#        'conv_coeff': 2.8571850508559584,
#        'q_hvac': -5.1321315261106415,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -6177.223607089955,
#        'heat_flux_total': -22.372993842276863}},
#      {'id': 'surf_17',
#       'properties': {'name': 'S2-office-core-wall-2',
#        'temperature': 28.33787259464589,
#        'conv_coeff': 1.388004551472794,
#        'q_hvac': -0.2745236279718399,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -13.234104383486473,
#        'heat_flux_total': -0.896072985709799}},
#      {'id': 'surf_18',
#       'properties': {'name': 'S2-office-core-wall-3',
#        'temperature': 26.544962424014827,
#        'conv_coeff': 1.8430632624646968,
#        'q_hvac': -0.33706318028838445,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -57.200338875266134,
#        'heat_flux_total': -3.1543933325596485}},
#      {'id': 'surf_19',
#       'properties': {'name': 'S2-office-core-wall-4',
#        'temperature': 29.350264546151283,
#        'conv_coeff': 1.6858219080314496,
#        'q_hvac': -0.3206830402121035,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': 8.156855568216566,
#        'heat_flux_total': 0.4727976820686953}},
#      {'id': 'surf_20',
#       'properties': {'name': 'S2-office-core-wall-5',
#        'temperature': 23.389921819650603,
#        'conv_coeff': 2.3680988356947013,
#        'q_hvac': -1.8564462384820393,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -1168.7983495461199,
#        'heat_flux_total': -11.702691899057395}},
#      {'id': 'surf_21',
#       'properties': {'name': 'S2-office-core-wall-6',
#        'temperature': 24.21260914882075,
#        'conv_coeff': 2.163650006587712,
#        'q_hvac': -0.31278845876004346,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -126.98818266872439,
#        'heat_flux_total': -7.546423023978009}},
#      {'id': 'surf_22',
#       'properties': {'name': 'S2-office-core-wall-7',
#        'temperature': 25.746888476423937,
#        'conv_coeff': 1.8592336814207728,
#        'q_hvac': -0.18228181723859344,
#        'heat_flux_hvac': -0.018587824293691015,
#        'q_total': -32.96008477934673,
#        'heat_flux_total': -3.3610388236459965}},
#      {'id': 'surf_23',
#       'properties': {'name': 'S2-office-core-wall-8',
#        'temperature': 25.09014670039353,
#        'conv_coeff': 2.0009994266473172,
#        'q_hvac': -0.25347461997888093,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -67.8801756112861,
#        'heat_flux_total': -4.977795320859354}},
#      {'id': 'surf_24',
#       'properties': {'name': 'S2-office-core-wall-9',
#        'temperature': 23.69948866042953,
#        'conv_coeff': 2.286724661432416,
#        'q_hvac': -3.294779189787492,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -1754.5052400220343,
#        'heat_flux_total': -9.89821570591904}},
#      {'id': 'surf_25',
#       'properties': {'name': 'S3-office-core-wall-0',
#        'temperature': 27.876870928470428,
#        'conv_coeff': 2.2195116067007192,
#        'q_hvac': -1.236873975262222,
#        'heat_flux_hvac': -0.0929391214684551,
#        'q_total': -571.3036151629169,
#        'heat_flux_total': -39.10540039139511}},
#      {'id': 'surf_26',
#       'properties': {'name': 'S3-office-core-wall-1',
#        'temperature': 24.89060879516061,
#        'conv_coeff': 2.1486798606572344,
#        'q_hvac': -0.5181573221692356,
#        'heat_flux_hvac': -0.018587824293691015,
#        'q_total': -188.94609221871323,
#        'heat_flux_total': -6.778051014386502}},
#      {'id': 'surf_27',
#       'properties': {'name': 'S3-office-core-wall-10',
#        'temperature': 25.23060750201647,
#        'conv_coeff': 2.642899980647254,
#        'q_hvac': -1.9580621034434007,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -1703.873455917938,
#        'heat_flux_total': -16.174819154913592}},
#      {'id': 'surf_28',
#       'properties': {'name': 'S3-office-core-wall-11',
#        'temperature': 26.440388584564968,
#        'conv_coeff': 2.861137555304525,
#        'q_hvac': -5.132131526110648,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -6239.6627039794785,
#        'heat_flux_total': -22.599139052339048}},
#      {'id': 'surf_29',
#       'properties': {'name': 'S3-office-core-wall-2',
#        'temperature': 28.34517375421091,
#        'conv_coeff': 1.4200787657659857,
#        'q_hvac': -0.27452362797184776,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -15.215678214923203,
#        'heat_flux_total': -1.0302441187224087}},
#      {'id': 'surf_30',
#       'properties': {'name': 'S3-office-core-wall-3',
#        'temperature': 26.529552426978647,
#        'conv_coeff': 1.8718809975212372,
#        'q_hvac': -0.33706318028839205,
#        'heat_flux_hvac': -0.018587824293691015,
#        'q_total': -61.45693984736933,
#        'heat_flux_total': -3.389129594438173}},
#      {'id': 'surf_31',
#       'properties': {'name': 'S3-office-core-wall-4',
#        'temperature': 24.04264329039705,
#        'conv_coeff': 2.4017338952708744,
#        'q_hvac': -1.734347815043606,
#        'heat_flux_hvac': -0.055763472881073056,
#        'q_total': -1256.3040647881874,
#        'heat_flux_total': -26.97841718155654}},
#      {'id': 'surf_32',
#       'properties': {'name': 'S3-office-core-wall-5',
#        'temperature': 23.450784683389603,
#        'conv_coeff': 2.3761238365248936,
#        'q_hvac': -1.8564462384820424,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -1182.604041837382,
#        'heat_flux_total': -11.840922555697652}},
#      {'id': 'surf_33',
#       'properties': {'name': 'S3-office-core-wall-6',
#        'temperature': 24.43641959011479,
#        'conv_coeff': 2.084522901651616,
#        'q_hvac': -0.24722484005155337,
#        'heat_flux_hvac': -0.0929391214684551,
#        'q_total': -84.41402424182395,
#        'heat_flux_total': -30.113184578974327}},
#      {'id': 'surf_34',
#       'properties': {'name': 'S3-office-core-wall-7',
#        'temperature': 25.19923093875403,
#        'conv_coeff': 1.7479182398543414,
#        'q_hvac': -0.18228181723860784,
#        'heat_flux_hvac': -0.018587824293691015,
#        'q_total': -25.680972670014334,
#        'heat_flux_total': -2.6187659027803605}},
#      {'id': 'surf_35',
#       'properties': {'name': 'S3-office-core-wall-8',
#        'temperature': 24.524161018457836,
#        'conv_coeff': 1.9434712944591503,
#        'q_hvac': -0.25347461997884624,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -57.29276241223949,
#        'heat_flux_total': -4.201398156185294}},
#      {'id': 'surf_36',
#       'properties': {'name': 'S3-office-core-wall-9',
#        'temperature': 23.61792826019816,
#        'conv_coeff': 2.2752782626426744,
#        'q_hvac': -3.294779189787482,
#        'heat_flux_hvac': -0.018587824293691015,
#        'q_total': -1706.4352150616005,
#        'heat_flux_total': -9.627023882039813}},
#      {'id': 'surf_37',
#       'properties': {'name': 'S4-office-core-roof',
#        'temperature': 25.571593591628663,
#        'conv_coeff': 1.7837300588321865,
#        'q_hvac': 393314.0445073071,
#        'heat_flux_hvac': 338.6543953878458,
#        'q_total': 371655.4001471182,
#        'heat_flux_total': 320.00569668727377}},
#      {'id': 'surf_38',
#       'properties': {'name': 'S4-office-core-wall-0',
#        'temperature': 30.026051476014796,
#        'conv_coeff': 2.208169104455114,
#        'q_hvac': -1.7288877398091975,
#        'heat_flux_hvac': -0.03717564858738204,
#        'q_total': -848.664834509303,
#        'heat_flux_total': -12.438683155989127}},
#      {'id': 'surf_39',
#       'properties': {'name': 'S4-office-core-wall-1',
#        'temperature': 24.512510879541725,
#        'conv_coeff': 2.4431209619520358,
#        'q_hvac': -0.518157322169228,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -333.8853065906609,
#        'heat_flux_total': -11.977446130010376}},
#      {'id': 'surf_40',
#       'properties': {'name': 'S4-office-core-wall-10',
#        'temperature': 25.298899086986452,
#        'conv_coeff': 2.9313198187431317,
#        'q_hvac': -1.95806210344339,
#        'heat_flux_hvac': -0.018587824293691015,
#        'q_total': -2673.1390148503424,
#        'heat_flux_total': -25.376027774230913}},
#      {'id': 'surf_41',
#       'properties': {'name': 'S4-office-core-wall-11',
#        'temperature': 26.326171116555916,
#        'conv_coeff': 2.8729450173289948,
#        'q_hvac': -5.132131526110633,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -6397.699767992248,
#        'heat_flux_total': -23.171526015302703}},
#      {'id': 'surf_42',
#       'properties': {'name': 'S4-office-core-wall-2',
#        'temperature': 28.773983022775734,
#        'conv_coeff': 1.7458864797686344,
#        'q_hvac': -0.27452362797183194,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -47.188437878978405,
#        'heat_flux_total': -3.195099811511321}},
#      {'id': 'surf_43',
#       'properties': {'name': 'S4-office-core-wall-3',
#        'temperature': 25.926040526050816,
#        'conv_coeff': 2.272614529802415,
#        'q_hvac': -0.3370631802883768,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -150.92846047869998,
#        'heat_flux_total': -8.32316274324344}},
#      {'id': 'surf_44',
#       'properties': {'name': 'S4-office-core-wall-4',
#        'temperature': 29.54562023391068,
#        'conv_coeff': 1.8082771248505658,
#        'q_hvac': -0.3206830402120951,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -44.559137811070414,
#        'heat_flux_total': -2.582791480842714}},
#      {'id': 'surf_45',
#       'properties': {'name': 'S4-office-core-wall-5',
#        'temperature': 23.70835894336388,
#        'conv_coeff': 2.5498955215257975,
#        'q_hvac': -1.8564462384820364,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -1548.100169769548,
#        'heat_flux_total': -15.500483314959212}},
#      {'id': 'surf_46',
#       'properties': {'name': 'S4-office-core-wall-6',
#        'temperature': 23.771477228355256,
#        'conv_coeff': 2.4285624999906097,
#        'q_hvac': -0.3127884587600282,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -198.5175095107989,
#        'heat_flux_total': -11.797137914346276}},
#      {'id': 'surf_47',
#       'properties': {'name': 'S4-office-core-wall-7',
#        'temperature': 24.97621989078849,
#        'conv_coeff': 2.201440740197442,
#        'q_hvac': -0.18228181723857903,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -73.07549336129614,
#        'heat_flux_total': -7.451727502786146}},
#      {'id': 'surf_48',
#       'properties': {'name': 'S4-office-core-wall-8',
#        'temperature': 24.57519592205857,
#        'conv_coeff': 2.3100038607106046,
#        'q_hvac': -0.2534746199789157,
#        'heat_flux_hvac': -0.018587824293691015,
#        'q_total': -120.23819629833628,
#        'heat_flux_total': -8.817318540095696}},
#      {'id': 'surf_49',
#       'properties': {'name': 'S4-office-core-wall-9',
#        'temperature': 23.50980249606853,
#        'conv_coeff': 2.340539126997833,
#        'q_hvac': -3.294779189787503,
#        'heat_flux_hvac': -0.01858782429369102,
#        'q_total': -1842.1240018845892,
#        'heat_flux_total': -10.392525660097442}}]}},
#   {'id': 'bldg_3981228_17029',
#    'properties': {'objects': [{'id': 'surf_1',
#       'properties': {'name': 'S1-office-core-wall-0',
#        'temperature': 23.053012700305413,
#        'conv_coeff': 2.2318851307241148,
#        'q_hvac': -1.2720483993402238,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -662.300875886415,
#        'heat_flux_total': -9.286183433281618}},
#      {'id': 'surf_2',
#       'properties': {'name': 'S1-office-core-wall-1',
#        'temperature': 26.36215057480795,
#        'conv_coeff': 1.896298592623195,
#        'q_hvac': 486450.54595869046,
#        'heat_flux_hvac': 467.692509275245,
#        'q_total': 454176.4356804771,
#        'heat_flux_total': 375.4508341564858}},
#      {'id': 'surf_3',
#       'properties': {'name': 'S1-office-core-wall-3',
#        'temperature': 29.534789150574824,
#        'conv_coeff': 2.3661353846268067,
#        'q_hvac': -0.9245368157005399,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -525.4561810165544,
#        'heat_flux_total': -10.136729558029103}},
#      {'id': 'surf_4',
#       'properties': {'name': 'S2-office-core-wall-0',
#        'temperature': 23.08026273519941,
#        'conv_coeff': 2.2907148152204617,
#        'q_hvac': -1.2720483993402236,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -713.248726352549,
#        'heat_flux_total': -10.000528079627916}},
#      {'id': 'surf_5',
#       'properties': {'name': 'S2-office-core-wall-1',
#        'temperature': 36.252851979538534,
#        'conv_coeff': 2.912924214024124,
#        'q_hvac': -0.9367931732267629,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -1472.3027650356237,
#        'heat_flux_total': -28.03102476595994}},
#      {'id': 'surf_6',
#       'properties': {'name': 'S2-office-core-wall-3',
#        'temperature': 30.72255100473453,
#        'conv_coeff': 2.567039737612999,
#        'q_hvac': -0.9245368157005399,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -729.2981663791268,
#        'heat_flux_total': -14.06910518294734}},
#      {'id': 'surf_7',
#       'properties': {'name': 'S3-office-core-wall-0',
#        'temperature': 23.070776963420982,
#        'conv_coeff': 2.2715426483789423,
#        'q_hvac': -1.2720483993402227,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -685.7395209897154,
#        'heat_flux_total': -9.614818900606847}},
#      {'id': 'surf_8',
#       'properties': {'name': 'S3-office-core-wall-1',
#        'temperature': 24.930766701783444,
#        'conv_coeff': 2.0050352753375535,
#        'q_hvac': -0.9367931732267588,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -326.35175403547555,
#        'heat_flux_total': -6.213378332928404}},
#      {'id': 'surf_9',
#       'properties': {'name': 'S3-office-core-wall-3',
#        'temperature': 31.468022209739534,
#        'conv_coeff': 2.7084424375520064,
#        'q_hvac': -0.9245368157005364,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -910.9751310846698,
#        'heat_flux_total': -17.573888882666928}},
#      {'id': 'surf_10',
#       'properties': {'name': 'S4-office-core-wall-0',
#        'temperature': 22.98231939061942,
#        'conv_coeff': 2.234515136305452,
#        'q_hvac': -1.272048399340225,
#        'heat_flux_hvac': -0.0178355113247826,
#        'q_total': -647.2773886535899,
#        'heat_flux_total': -9.075537693058395}},
#      {'id': 'surf_11',
#       'properties': {'name': 'S4-office-core-wall-1',
#        'temperature': 24.00468052022717,
#        'conv_coeff': 2.1776231075134143,
#        'q_hvac': -0.9367931732267668,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -440.22804919990114,
#        'heat_flux_total': -8.381457702073956}},
#      {'id': 'surf_12',
#       'properties': {'name': 'S4-office-core-wall-3',
#        'temperature': 31.48024519409252,
#        'conv_coeff': 2.7536049121963413,
#        'q_hvac': -0.9245368157005437,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -1001.7449255632138,
#        'heat_flux_total': -19.324955654565493}},
#      {'id': 'surf_13',
#       'properties': {'name': 'S5-office-core-roof',
#        'temperature': 27.169297571690606,
#        'conv_coeff': 1.908962519982248,
#        'q_hvac': 126374.82922825716,
#        'heat_flux_hvac': 535.1140254027351,
#        'q_total': 120105.2398323036,
#        'heat_flux_total': 508.5664507015157}},
#      {'id': 'surf_14',
#       'properties': {'name': 'S5-office-core-wall-0',
#        'temperature': 22.897664326363678,
#        'conv_coeff': 2.2654355167166846,
#        'q_hvac': -1.2720483993402307,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -684.4587047012459,
#        'heat_flux_total': -9.596860453876449}},
#      {'id': 'surf_15',
#       'properties': {'name': 'S5-office-core-wall-1',
#        'temperature': 23.73054713453526,
#        'conv_coeff': 2.3433748098205918,
#        'q_hvac': -0.936793173226736,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -588.9121945354449,
#        'heat_flux_total': -11.212240241632587}},
#      {'id': 'surf_16',
#       'properties': {'name': 'S5-office-core-wall-3',
#        'temperature': 31.340665751773113,
#        'conv_coeff': 2.7996699766412454,
#        'q_hvac': -0.924536815700561,
#        'heat_flux_hvac': -0.017835511324782595,
#        'q_total': -1075.0807160837437,
#        'heat_flux_total': -20.739697934297585}}]}},
#   {'id': 'bldg_3981221_15715',
#    'properties': {'objects': [{'id': 'surf_1',
#       'properties': {'name': 'S1-retail-core-roof',
#        'temperature': 23.350687282292967,
#        'conv_coeff': 1.8674935492896931,
#        'q_hvac': 24827.765339993162,
#        'heat_flux_hvac': 99.78724609858206,
#        'q_total': 18438.286268538468,
#        'heat_flux_total': 74.1067826410857}},
#      {'id': 'surf_2',
#       'properties': {'name': 'S1-retail-core-wall-0',
#        'temperature': 25.48974069646585,
#        'conv_coeff': 1.7246222252168912,
#        'q_hvac': -0.8488122165888511,
#        'heat_flux_hvac': -0.021790210322822568,
#        'q_total': -109.22469818681074,
#        'heat_flux_total': -2.8039525108417056}},
#      {'id': 'surf_3',
#       'properties': {'name': 'S1-retail-core-wall-2',
#        'temperature': 26.46803327918595,
#        'conv_coeff': 2.282983570219127,
#        'q_hvac': -0.843852380426752,
#        'heat_flux_hvac': -0.021790210322822565,
#        'q_total': -289.94397673376443,
#        'heat_flux_total': -7.487020693914732}},
#      {'id': 'surf_4',
#       'properties': {'name': 'S1-retail-core-wall-3',
#        'temperature': 25.70854445750486,
#        'conv_coeff': 1.6984675483651237,
#        'q_hvac': -1.2819902983483074,
#        'heat_flux_hvac': -0.09977190382361864,
#        'q_total': -146.89932813101456,
#        'heat_flux_total': -8.081426902941208}},
#      {'id': 'surf_5',
#       'properties': {'name': 'S1-retail-core-wall-4',
#        'temperature': 25.32657035241726,
#        'conv_coeff': 1.65836574143089,
#        'q_hvac': -0.9021735101926633,
#        'heat_flux_hvac': -0.16652917938575612,
#        'q_total': -79.9891864319534,
#        'heat_flux_total': -12.485900825351194}},
#      {'id': 'surf_6',
#       'properties': {'name': 'S2-retail-core-roof',
#        'temperature': 24.23980419666781,
#        'conv_coeff': 1.8612080447003096,
#        'q_hvac': 18687.359324111952,
#        'heat_flux_hvac': 99.7376894594475,
#        'q_total': 13953.8591461535,
#        'heat_flux_total': 67.3228090457775}},
#      {'id': 'surf_7',
#       'properties': {'name': 'S2-retail-core-wall-0',
#        'temperature': 25.34172636252035,
#        'conv_coeff': 1.762759010991631,
#        'q_hvac': -0.8488122165888511,
#        'heat_flux_hvac': -0.021790210322822568,
#        'q_total': -121.98256559412559,
#        'heat_flux_total': -3.131465014364885}},
#      {'id': 'surf_8',
#       'properties': {'name': 'S2-retail-core-wall-2',
#        'temperature': 26.53622074049541,
#        'conv_coeff': 2.5271527784703323,
#        'q_hvac': -0.843852380426752,
#        'heat_flux_hvac': -0.021790210322822565,
#        'q_total': -500.832554028732,
#        'heat_flux_total': -12.932649053242502}},
#      {'id': 'surf_9',
#       'properties': {'name': 'S2-retail-core-wall-3',
#        'temperature': 25.596796928841144,
#        'conv_coeff': 2.05716326863908,
#        'q_hvac': -1.4930072795928273,
#        'heat_flux_hvac': -0.021790210322822568,
#        'q_total': -416.66042019945843,
#        'heat_flux_total': -6.08109438811168}},
#      {'id': 'surf_10',
#       'properties': {'name': 'S2-retail-core-wall-4',
#        'temperature': 24.50589651976274,
#        'conv_coeff': 1.7591546786482717,
#        'q_hvac': -0.46427991689866493,
#        'heat_flux_hvac': -0.021790210322822568,
#        'q_total': -69.09377059791909,
#        'heat_flux_total': -3.242801892837679}}]}},
#   {'id': 'bldg_3981158_873',
#    'properties': {'objects': [{'id': 'surf_1',
#       'properties': {'name': 'S2-office-core-wall-0',
#        'temperature': 25.403596962311155,
#        'conv_coeff': 1.7526144151116758,
#        'q_hvac': -0.3183581504039598,
#        'heat_flux_hvac': -0.04427869606642791,
#        'q_total': -45.78524084248588,
#        'heat_flux_total': -6.181325822166729}},
#      {'id': 'surf_2',
#       'properties': {'name': 'S2-office-core-wall-1',
#        'temperature': 26.164387100209193,
#        'conv_coeff': 1.5470395541444897,
#        'q_hvac': -0.07992861713974204,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -16.974721901446042,
#        'heat_flux_total': -1.5019178281550332}},
#      {'id': 'surf_3',
#       'properties': {'name': 'S2-office-core-wall-10',
#        'temperature': 24.35472413074503,
#        'conv_coeff': 1.9927923022958336,
#        'q_hvac': -0.13446924659754964,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -101.83742847253879,
#        'heat_flux_total': -5.355872828917156}},
#      {'id': 'surf_4',
#       'properties': {'name': 'S2-office-core-wall-11',
#        'temperature': 26.003326828120226,
#        'conv_coeff': 1.5867178928368906,
#        'q_hvac': -0.19824246577443633,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -48.868449384682755,
#        'heat_flux_total': -1.7433222449375234}},
#      {'id': 'surf_5',
#       'properties': {'name': 'S2-office-core-wall-2',
#        'temperature': 25.25701837700666,
#        'conv_coeff': 1.8060040182555408,
#        'q_hvac': -2.522067988192866,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -1172.7650301433985,
#        'heat_flux_total': -3.2885164721021196}},
#      {'id': 'surf_6',
#       'properties': {'name': 'S2-office-core-wall-3',
#        'temperature': 25.303609281660837,
#        'conv_coeff': 1.9275599365711544,
#        'q_hvac': -1.4082340180255286,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -785.7084751535691,
#        'heat_flux_total': -3.945775850142745}},
#      {'id': 'surf_7',
#       'properties': {'name': 'S2-office-core-wall-4',
#        'temperature': 27.682873064521566,
#        'conv_coeff': 1.9831232064193387,
#        'q_hvac': -2.5062870360791916,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -1415.2583653284173,
#        'heat_flux_total': -3.993472762888419}},
#      {'id': 'surf_8',
#       'properties': {'name': 'S2-office-core-wall-5',
#        'temperature': 33.17239311928321,
#        'conv_coeff': 2.6113954773363433,
#        'q_hvac': -0.1007518953764249,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -185.23187987688559,
#        'heat_flux_total': -13.0019446575963}},
#      {'id': 'surf_9',
#       'properties': {'name': 'S2-office-core-wall-6',
#        'temperature': 28.677160361736806,
#        'conv_coeff': 2.9128900661095316,
#        'q_hvac': -0.4001474267613716,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -1141.3036338821853,
#        'heat_flux_total': -20.17097891707866}},
#      {'id': 'surf_10',
#       'properties': {'name': 'S2-office-core-wall-7',
#        'temperature': 31.81796681823309,
#        'conv_coeff': 2.5853821434427053,
#        'q_hvac': -1.2080620069312142,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -2314.6425604537435,
#        'heat_flux_total': -13.55003796715321}},
#      {'id': 'surf_11',
#       'properties': {'name': 'S2-office-core-wall-8',
#        'temperature': 24.732976361440233,
#        'conv_coeff': 1.9550720690109855,
#        'q_hvac': -0.14274802485580493,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -95.76032104737986,
#        'heat_flux_total': -4.7441814320417794}},
#      {'id': 'surf_12',
#       'properties': {'name': 'S2-office-core-wall-9',
#        'temperature': 29.492829027168217,
#        'conv_coeff': 1.4806582761844629,
#        'q_hvac': -0.197590946263838,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': 66.54564974401303,
#        'heat_flux_total': 2.3817623869928233}},
#      {'id': 'surf_13',
#       'properties': {'name': 'S3-office-core-wall-0',
#        'temperature': 25.601327749910194,
#        'conv_coeff': 1.662901292864856,
#        'q_hvac': -0.10847821150367987,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -33.799870371476,
#        'heat_flux_total': -2.2035267253450366}},
#      {'id': 'surf_14',
#       'properties': {'name': 'S3-office-core-wall-1',
#        'temperature': 26.244884087362557,
#        'conv_coeff': 1.432215043644593,
#        'q_hvac': -0.07992861713974206,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -12.67060257125193,
#        'heat_flux_total': -1.1210907610574243}},
#      {'id': 'surf_15',
#       'properties': {'name': 'S3-office-core-wall-10',
#        'temperature': 24.373910453771142,
#        'conv_coeff': 1.9429782550797292,
#        'q_hvac': -0.13446924659754964,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -93.0107088497531,
#        'heat_flux_total': -4.891654628347649}},
#      {'id': 'surf_16',
#       'properties': {'name': 'S3-office-core-wall-11',
#        'temperature': 26.02500235417084,
#        'conv_coeff': 1.5280337424558323,
#        'q_hvac': -0.19824246577443633,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -40.84583206955144,
#        'heat_flux_total': -1.457125170870485}},
#      {'id': 'surf_17',
#       'properties': {'name': 'S3-office-core-wall-2',
#        'temperature': 25.24640581630622,
#        'conv_coeff': 1.842452730817912,
#        'q_hvac': -2.5220679881928665,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -1238.539840549215,
#        'heat_flux_total': -3.472953713927511}},
#      {'id': 'surf_18',
#       'properties': {'name': 'S3-office-core-wall-3',
#        'temperature': 25.319796321622487,
#        'conv_coeff': 1.9062445230772969,
#        'q_hvac': -1.4082340180255288,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -789.4689553284096,
#        'heat_flux_total': -3.9646607321671183}},
#      {'id': 'surf_19',
#       'properties': {'name': 'S3-office-core-wall-4',
#        'temperature': 27.56348058501182,
#        'conv_coeff': 1.7685125186856308,
#        'q_hvac': -2.5062870360791916,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -809.5453941183891,
#        'heat_flux_total': -2.2843161085879524}},
#      {'id': 'surf_20',
#       'properties': {'name': 'S3-office-core-wall-5',
#        'temperature': 32.79530967337996,
#        'conv_coeff': 2.617045229110192,
#        'q_hvac': -0.10075189537642489,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -185.43529264431123,
#        'heat_flux_total': -13.016222769692742}},
#      {'id': 'surf_21',
#       'properties': {'name': 'S3-office-core-wall-6',
#        'temperature': 28.070697297190428,
#        'conv_coeff': 2.653038713778832,
#        'q_hvac': -0.4001474267613716,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -767.6407675983489,
#        'heat_flux_total': -13.566999420168994}},
#      {'id': 'surf_22',
#       'properties': {'name': 'S3-office-core-wall-7',
#        'temperature': 31.692510860961505,
#        'conv_coeff': 2.4811044552243846,
#        'q_hvac': -1.2080620069312145,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -1964.9427471594859,
#        'heat_flux_total': -11.502877067150274}},
#      {'id': 'surf_23',
#       'properties': {'name': 'S3-office-core-wall-8',
#        'temperature': 24.578997848608452,
#        'conv_coeff': 1.9056320863977776,
#        'q_hvac': -0.14274802485580493,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -82.4018188476633,
#        'heat_flux_total': -4.0823712229424585}},
#      {'id': 'surf_24',
#       'properties': {'name': 'S3-office-core-wall-9',
#        'temperature': 29.33171630489076,
#        'conv_coeff': 1.5116492524925451,
#        'q_hvac': -0.19759094626383797,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': 84.08528839427737,
#        'heat_flux_total': 3.009530720149772}},
#      {'id': 'surf_25',
#       'properties': {'name': 'S4-office-core-wall-0',
#        'temperature': 25.639979510449837,
#        'conv_coeff': 1.75333215580632,
#        'q_hvac': -0.10847821150367669,
#        'heat_flux_hvac': -0.007072057837467726,
#        'q_total': -42.48561800511762,
#        'heat_flux_total': -2.7697796970276225}},
#      {'id': 'surf_26',
#       'properties': {'name': 'S4-office-core-wall-1',
#        'temperature': 26.251074536314356,
#        'conv_coeff': 1.5702054384890902,
#        'q_hvac': -0.07992861713974088,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -18.44598191286801,
#        'heat_flux_total': -1.6320944315678052}},
#      {'id': 'surf_27',
#       'properties': {'name': 'S4-office-core-wall-10',
#        'temperature': 24.421823133105846,
#        'conv_coeff': 2.0183136533055923,
#        'q_hvac': -0.1344692465975531,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -107.63378249255327,
#        'heat_flux_total': -5.660716887415125}},
#      {'id': 'surf_28',
#       'properties': {'name': 'S4-office-core-wall-11',
#        'temperature': 26.0061183357238,
#        'conv_coeff': 1.6510327828348916,
#        'q_hvac': -0.19824246577443475,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -57.46729823832668,
#        'heat_flux_total': -2.0500756753443494}},
#      {'id': 'surf_29',
#       'properties': {'name': 'S4-office-core-wall-2',
#        'temperature': 25.27602357249775,
#        'conv_coeff': 1.8975324318995743,
#        'q_hvac': -2.5220679881928696,
#        'heat_flux_hvac': -0.007072057837467726,
#        'q_total': -1354.280343669793,
#        'heat_flux_total': -3.7974983082993807}},
#      {'id': 'surf_30',
#       'properties': {'name': 'S4-office-core-wall-3',
#        'temperature': 25.258461485173054,
#        'conv_coeff': 1.98778852142568,
#        'q_hvac': -1.40823401802553,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -889.3835904896513,
#        'heat_flux_total': -4.466425403113289}},
#      {'id': 'surf_31',
#       'properties': {'name': 'S4-office-core-wall-4',
#        'temperature': 27.519121074524453,
#        'conv_coeff': 3.0245236683288277,
#        'q_hvac': 17.295879647200614,
#        'heat_flux_hvac': 2.596319962247392,
#        'q_total': -4758.113090540828,
#        'heat_flux_total': -700.5727332219915}},
#      {'id': 'surf_32',
#       'properties': {'name': 'S4-office-core-wall-5',
#        'temperature': 33.05065163269091,
#        'conv_coeff': 2.6604324673046507,
#        'q_hvac': -0.10075189537642287,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -198.38230756669088,
#        'heat_flux_total': -13.92501002388349}},
#      {'id': 'surf_33',
#       'properties': {'name': 'S4-office-core-wall-6',
#        'temperature': 28.030603190415487,
#        'conv_coeff': 2.6125115018712055,
#        'q_hvac': -0.4001474267613716,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -723.9506635990631,
#        'heat_flux_total': -12.794836657787446}},
#      {'id': 'surf_34',
#       'properties': {'name': 'S4-office-core-wall-7',
#        'temperature': 31.895157307265077,
#        'conv_coeff': 2.587925121229636,
#        'q_hvac': -1.2080620069312162,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -2312.5815810285744,
#        'heat_flux_total': -13.537972886376703}},
#      {'id': 'surf_35',
#       'properties': {'name': 'S4-office-core-wall-8',
#        'temperature': 24.573933050141893,
#        'conv_coeff': 1.8925724495030536,
#        'q_hvac': -0.14274802485580823,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -82.25054530733846,
#        'heat_flux_total': -4.07487679191583}},
#      {'id': 'surf_36',
#       'properties': {'name': 'S4-office-core-wall-9',
#        'temperature': 29.329395502429808,
#        'conv_coeff': 1.487989863159604,
#        'q_hvac': -0.19759094626383683,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': 83.11004366187326,
#        'heat_flux_total': 2.9746253396975986}},
#      {'id': 'surf_37',
#       'properties': {'name': 'S5-office-core-wall-0',
#        'temperature': 25.687990596298366,
#        'conv_coeff': 1.834404731025061,
#        'q_hvac': -0.10847821150368304,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -49.482543994024134,
#        'heat_flux_total': -3.2259327308221577}},
#      {'id': 'surf_38',
#       'properties': {'name': 'S5-office-core-wall-1',
#        'temperature': 26.298389829661264,
#        'conv_coeff': 1.6497227617236045,
#        'q_hvac': -0.07992861713974322,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -22.517668016685345,
#        'heat_flux_total': -1.9923558830059285}},
#      {'id': 'surf_39',
#       'properties': {'name': 'S5-office-core-wall-10',
#        'temperature': 24.44080968673941,
#        'conv_coeff': 2.0691963715957935,
#        'q_hvac': -0.13446924659754614,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -118.91273029582143,
#        'heat_flux_total': -6.253903606526163}},
#      {'id': 'surf_40',
#       'properties': {'name': 'S5-office-core-wall-11',
#        'temperature': 26.02732080725861,
#        'conv_coeff': 1.7476171098769957,
#        'q_hvac': -0.1982424657744379,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -70.32564145119723,
#        'heat_flux_total': -2.5087813645627794}},
#      {'id': 'surf_41',
#       'properties': {'name': 'S5-office-core-wall-2',
#        'temperature': 25.292872342481036,
#        'conv_coeff': 1.9807599087567949,
#        'q_hvac': -2.5220679881928634,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -1535.3043990671958,
#        'heat_flux_total': -4.305102621797975}},
#      {'id': 'surf_42',
#       'properties': {'name': 'S5-office-core-wall-3',
#        'temperature': 25.184062288225284,
#        'conv_coeff': 2.047046014980404,
#        'q_hvac': -1.4082340180255275,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -972.3877144999699,
#        'heat_flux_total': -4.88326660864841}},
#      {'id': 'surf_43',
#       'properties': {'name': 'S5-office-core-wall-4',
#        'temperature': 27.009717780610185,
#        'conv_coeff': 1.1718726240664286,
#        'q_hvac': -2.5062870360791942,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': 280.4070193558347,
#        'heat_flux_total': 0.7912320617588406}},
#      {'id': 'surf_44',
#       'properties': {'name': 'S5-office-core-wall-5',
#        'temperature': 33.0606444761479,
#        'conv_coeff': 2.659457429164065,
#        'q_hvac': -0.1007518953764269,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -198.15080003873584,
#        'heat_flux_total': -13.908759861825034}},
#      {'id': 'surf_45',
#       'properties': {'name': 'S5-office-core-wall-6',
#        'temperature': 28.005987756479332,
#        'conv_coeff': 2.5893876861866207,
#        'q_hvac': -0.4001474267613716,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -701.8753913196826,
#        'heat_flux_total': -12.404686448397927}},
#      {'id': 'surf_46',
#       'properties': {'name': 'S5-office-core-wall-7',
#        'temperature': 31.98706552045506,
#        'conv_coeff': 2.6445091475503717,
#        'q_hvac': -1.208062006931212,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -2528.7778470394223,
#        'heat_flux_total': -14.803597075119518}},
#      {'id': 'surf_47',
#       'properties': {'name': 'S5-office-core-wall-8',
#        'temperature': 24.596121414504513,
#        'conv_coeff': 1.9212152095671,
#        'q_hvac': -0.14274802485580165,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -85.45023999298294,
#        'heat_flux_total': -4.233396854816884}},
#      {'id': 'surf_48',
#       'properties': {'name': 'S5-office-core-wall-9',
#        'temperature': 29.378315603655075,
#        'conv_coeff': 1.4997109276829408,
#        'q_hvac': -0.19759094626383913,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': 81.99367775756183,
#        'heat_flux_total': 2.9346690340451516}},
#      {'id': 'surf_49',
#       'properties': {'name': 'S6-office-core-wall-0',
#        'temperature': 25.688178393954516,
#        'conv_coeff': 1.997928610426888,
#        'q_hvac': -0.10847821150367626,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -70.19638917701593,
#        'heat_flux_total': -4.576337656750787}},
#      {'id': 'surf_50',
#       'properties': {'name': 'S6-office-core-wall-1',
#        'temperature': 26.345893044955606,
#        'conv_coeff': 1.8264307469544303,
#        'q_hvac': -0.07992861713973766,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -33.98921343566477,
#        'heat_flux_total': -3.0073544603782603}},
#      {'id': 'surf_51',
#       'properties': {'name': 'S6-office-core-wall-10',
#        'temperature': 24.41025336429385,
#        'conv_coeff': 2.160689007937027,
#        'q_hvac': -0.13446924659755927,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -142.02103457552343,
#        'heat_flux_total': -7.469224347341108}},
#      {'id': 'surf_52',
#       'properties': {'name': 'S6-office-core-wall-11',
#        'temperature': 26.00714332482304,
#        'conv_coeff': 1.9294928435035432,
#        'q_hvac': -0.19824246577443552,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -106.16005500930174,
#        'heat_flux_total': -3.787130300874986}},
#      {'id': 'surf_53',
#       'properties': {'name': 'S6-office-core-wall-2',
#        'temperature': 25.316021492038807,
#        'conv_coeff': 2.0867661971635187,
#        'q_hvac': -2.5220679881928687,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -1903.3278898761234,
#        'heat_flux_total': -5.337066638918852}},
#      {'id': 'surf_54',
#       'properties': {'name': 'S6-office-core-wall-3',
#        'temperature': 25.100695322068272,
#        'conv_coeff': 2.061957498412596,
#        'q_hvac': -1.4082340180255282,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -1016.8979061933283,
#        'heat_flux_total': -5.106793839196036}},
#      {'id': 'surf_55',
#       'properties': {'name': 'S6-office-core-wall-4',
#        'temperature': 27.21228648842366,
#        'conv_coeff': 1.5207463604619305,
#        'q_hvac': -2.5062870360791822,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -416.8786909589461,
#        'heat_flux_total': -1.1763178643263577}},
#      {'id': 'surf_56',
#       'properties': {'name': 'S6-office-core-wall-5',
#        'temperature': 33.1018880401786,
#        'conv_coeff': 2.622324701776924,
#        'q_hvac': -0.10075189537642364,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -187.46809971758802,
#        'heat_flux_total': -13.158911193974307}},
#      {'id': 'surf_57',
#       'properties': {'name': 'S6-office-core-wall-6',
#        'temperature': 28.39330149260993,
#        'conv_coeff': 2.682478391175859,
#        'q_hvac': -0.40014742676137116,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -812.9092996430531,
#        'heat_flux_total': -14.367058736877613}},
#      {'id': 'surf_58',
#       'properties': {'name': 'S6-office-core-wall-7',
#        'temperature': 31.99360862820521,
#        'conv_coeff': 2.651411882859104,
#        'q_hvac': -1.208062006931219,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -2567.3277920509195,
#        'heat_flux_total': -15.029270458760601}},
#      {'id': 'surf_59',
#       'properties': {'name': 'S6-office-core-wall-8',
#        'temperature': 24.509079083533575,
#        'conv_coeff': 1.93010280124337,
#        'q_hvac': -0.14274802485580845,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -86.9879640831186,
#        'heat_flux_total': -4.309579160767966}},
#      {'id': 'surf_60',
#       'properties': {'name': 'S6-office-core-wall-9',
#        'temperature': 29.30057149246157,
#        'conv_coeff': 1.4896907644915738,
#        'q_hvac': -0.19759094626383608,
#        'heat_flux_hvac': -0.007072057837467726,
#        'q_total': 80.61179223231623,
#        'heat_flux_total': 2.8852094077612724}},
#      {'id': 'surf_61',
#       'properties': {'name': 'S7-office-core-wall-0',
#        'temperature': 25.79670643709281,
#        'conv_coeff': 2.2055756741384482,
#        'q_hvac': -0.10847821150367708,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -104.93770759600989,
#        'heat_flux_total': -6.841240532667727}},
#      {'id': 'surf_62',
#       'properties': {'name': 'S7-office-core-wall-1',
#        'temperature': 26.40860716019955,
#        'conv_coeff': 2.0752022814422437,
#        'q_hvac': -0.07992861713974404,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -57.163337066401674,
#        'heat_flux_total': -5.057793320876035}},
#      {'id': 'surf_63',
#       'properties': {'name': 'S7-office-core-wall-10',
#        'temperature': 24.44793133169211,
#        'conv_coeff': 2.2693881383455508,
#        'q_hvac': -0.13446924659754692,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -172.02270270227163,
#        'heat_flux_total': -9.047083505338637}},
#      {'id': 'surf_64',
#       'properties': {'name': 'S7-office-core-wall-11',
#        'temperature': 26.009416098935148,
#        'conv_coeff': 2.1680245588201443,
#        'q_hvac': -0.19824246577443388,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -173.20764026358273,
#        'heat_flux_total': -6.17897101435939}},
#      {'id': 'surf_65',
#       'properties': {'name': 'S7-office-core-wall-2',
#        'temperature': 25.38617475252992,
#        'conv_coeff': 2.216724993151789,
#        'q_hvac': -2.5220679881928696,
#        'heat_flux_hvac': -0.007072057837467726,
#        'q_total': -2452.1842724704998,
#        'heat_flux_total': -6.8760989331878}},
#      {'id': 'surf_66',
#       'properties': {'name': 'S7-office-core-wall-3',
#        'temperature': 24.975503710160684,
#        'conv_coeff': 2.0554310058590146,
#        'q_hvac': -1.4082340180255313,
#        'heat_flux_hvac': -0.007072057837467724,
#        'q_total': -1042.7574732226471,
#        'heat_flux_total': -5.236658869682669}},
#      {'id': 'surf_67',
#       'properties': {'name': 'S7-office-core-wall-4',
#        'temperature': 27.1979611341394,
#        'conv_coeff': 1.7283862697662982,
#        'q_hvac': -2.506287036079195,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -713.0959651124106,
#        'heat_flux_total': -2.012162149164339}},
#      {'id': 'surf_68',
#       'properties': {'name': 'S7-office-core-wall-5',
#        'temperature': 33.42432716570777,
#        'conv_coeff': 2.7728919170939252,
#        'q_hvac': -0.10075189537642211,
#        'heat_flux_hvac': -0.007072057837467725,
#        'q_total': -235.16026963742027,
#        'heat_flux_total': -16.50655823135543}},
#      {'id': 'surf_69',
#       'properties': {'name': 'S7-office-core-wall-6',
#        'temperature': 28.36059047935102,
#        'conv_coeff': 2.675477161123286,
#        'q_hvac': -0.40014742676137205,
#        'heat_flux_hvac': -0.007072057837467726,
#        'q_total': -815.9420532428824,
#        'heat_flux_total': -14.420658503939366}},
#      {'id': 'surf_70',
# ...
#        'temperature': 25.370530970109147,
#        'conv_coeff': 2.515095119672388,
#        'q_hvac': -0.8976425476748761,
#        'heat_flux_hvac': -0.020307976482205704,
#        'q_total': -594.6587296680601,
#        'heat_flux_total': -13.453367967369676}},
#      {'id': 'surf_12',
#       'properties': {'name': 'S3-office-core-wall-1',
#        'temperature': 30.682632756158213,
#        'conv_coeff': 2.6571061539531025,
#        'q_hvac': -1.4857712790467754,
#        'heat_flux_hvac': -0.020307976482205708,
#        'q_total': -1218.4011680710998,
#        'heat_flux_total': -16.65347999118301}},
#      {'id': 'surf_13',
#       'properties': {'name': 'S3-office-core-wall-2',
#        'temperature': 23.14834842005009,
#        'conv_coeff': 2.408481352553674,
#        'q_hvac': -0.9068537290756725,
#        'heat_flux_hvac': -0.020307976482205704,
#        'q_total': -507.81668804708664,
#        'heat_flux_total': -11.371987595665805}},
#      {'id': 'surf_14',
#       'properties': {'name': 'S3-office-core-wall-3',
#        'temperature': 23.328176854467248,
#        'conv_coeff': 2.3807731253043705,
#        'q_hvac': -0.6762199992717252,
#        'heat_flux_hvac': -0.020307976482205704,
#        'q_total': -355.1431920541352,
#        'heat_flux_total': -10.665522462834986}},
#      {'id': 'surf_15',
#       'properties': {'name': 'S3-office-core-wall-4',
#        'temperature': 23.063659647605682,
#        'conv_coeff': 2.379626428441377,
#        'q_hvac': -0.8012088177245278,
#        'heat_flux_hvac': -0.020307976482205708,
#        'q_total': -396.0442220906239,
#        'heat_flux_total': -10.038402686295878}},
#      {'id': 'surf_16',
#       'properties': {'name': 'S4-office-core-roof',
#        'temperature': 27.53182306142852,
#        'conv_coeff': 1.9812480099893977,
#        'q_hvac': 84716.32242139004,
#        'heat_flux_hvac': 481.6028339260465,
#        'q_total': 79358.3881263988,
#        'heat_flux_total': 451.14357570161474}},
#      {'id': 'surf_17',
#       'properties': {'name': 'S4-office-core-wall-0',
#        'temperature': 25.215647281714787,
#        'conv_coeff': 2.5609551142659415,
#        'q_hvac': -0.8976425476748717,
#        'heat_flux_hvac': -0.020307976482205708,
#        'q_total': -665.7216200589909,
#        'heat_flux_total': -15.061071958846865}},
#      {'id': 'surf_18',
#       'properties': {'name': 'S4-office-core-wall-1',
#        'temperature': 31.008548428721394,
#        'conv_coeff': 2.7779408130962713,
#        'q_hvac': -1.4857712790467734,
#        'heat_flux_hvac': -0.020307976482205708,
#        'q_total': -1457.5927136294545,
#        'heat_flux_total': -19.922823227551095}},
#      {'id': 'surf_19',
#       'properties': {'name': 'S4-office-core-wall-2',
#        'temperature': 23.18171289641872,
#        'conv_coeff': 2.4664177133172855,
#        'q_hvac': -0.906853729075688,
#        'heat_flux_hvac': -0.020307976482205708,
#        'q_total': -558.9117884329868,
#        'heat_flux_total': -12.516205305450425}},
#      {'id': 'surf_20',
#       'properties': {'name': 'S4-office-core-wall-3',
#        'temperature': 23.25585390832622,
#        'conv_coeff': 2.4555835828022308,
#        'q_hvac': -0.6762199992717441,
#        'heat_flux_hvac': -0.020307976482205708,
#        'q_total': -407.03843916212725,
#        'heat_flux_total': -12.224020376150385}},
#      {'id': 'surf_21',
#       'properties': {'name': 'S4-office-core-wall-4',
#        'temperature': 23.11326581444537,
#        'conv_coeff': 2.503824259856149,
#        'q_hvac': -0.8012088177245285,
#        'heat_flux_hvac': -0.020307976482205708,
#        'q_total': -509.9895218729014,
#        'heat_flux_total': -12.926536737052121}}]}},
#   {'id': 'bldg_3981195_5711',
#    'properties': {'objects': [{'id': 'surf_1',
#       'properties': {'name': 'S1-office-core-wall-0',
#        'temperature': 24.463545381284302,
#        'conv_coeff': 2.244454362740598,
#        'q_hvac': -2.86455316403598,
#        'heat_flux_hvac': -0.09065143819827699,
#        'q_total': -1324.5695324897595,
#        'heat_flux_total': -70.718960753489}},
#      {'id': 'surf_2',
#       'properties': {'name': 'S1-office-core-wall-1',
#        'temperature': 29.664033802721356,
#        'conv_coeff': 2.5528353812761346,
#        'q_hvac': -0.18071334668527395,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -129.70701413319537,
#        'heat_flux_total': -13.013014911462045}},
#      {'id': 'surf_3',
#       'properties': {'name': 'S1-office-core-wall-2',
#        'temperature': 29.91319984891388,
#        'conv_coeff': 2.474834959713228,
#        'q_hvac': -0.13888395199843548,
#        'heat_flux_hvac': -0.0181302876396554,
#        'q_total': -92.21991109419612,
#        'heat_flux_total': -12.038637223255703}},
#      {'id': 'surf_4',
#       'properties': {'name': 'S1-office-core-wall-3',
#        'temperature': 28.99620384136589,
#        'conv_coeff': 2.7086168575346363,
#        'q_hvac': -2.3922013838384886,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -2198.498113732664,
#        'heat_flux_total': -16.66222728842973}},
#      {'id': 'surf_5',
#       'properties': {'name': 'S1-office-core-wall-4',
#        'temperature': 25.71849482312769,
#        'conv_coeff': 1.662343157585729,
#        'q_hvac': -2.3206740831218355,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -258.57806978595386,
#        'heat_flux_total': -2.0201435507995478}},
#      {'id': 'surf_6',
#       'properties': {'name': 'S2-office-core-wall-0',
#        'temperature': 23.27711434034977,
#        'conv_coeff': 2.1564330223856563,
#        'q_hvac': -3.430135162808857,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -1538.9814891880487,
#        'heat_flux_total': -8.134424956081352}},
#      {'id': 'surf_7',
#       'properties': {'name': 'S2-office-core-wall-1',
#        'temperature': 29.717481938232414,
#        'conv_coeff': 2.4985349189420227,
#        'q_hvac': -0.18071334668527397,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -125.82561767491818,
#        'heat_flux_total': -12.623609062237959}},
#      {'id': 'surf_8',
#       'properties': {'name': 'S2-office-core-wall-2',
#        'temperature': 29.93356317508584,
#        'conv_coeff': 2.4625270873243807,
#        'q_hvac': -0.13888395199843548,
#        'heat_flux_hvac': -0.0181302876396554,
#        'q_total': -91.46814857281923,
#        'heat_flux_total': -11.940500105517081}},
#      {'id': 'surf_9',
#       'properties': {'name': 'S2-office-core-wall-3',
#        'temperature': 30.203560427113572,
#        'conv_coeff': 2.646385595764877,
#        'q_hvac': -2.392201383838489,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -2032.033535229819,
#        'heat_flux_total': -15.400606627869845}},
#      {'id': 'surf_10',
#       'properties': {'name': 'S2-office-core-wall-4',
#        'temperature': 25.715628777829426,
#        'conv_coeff': 1.671708197808125,
#        'q_hvac': -2.3206740831218355,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -244.931958260979,
#        'heat_flux_total': -1.913533178877873}},
#      {'id': 'surf_11',
#       'properties': {'name': 'S3-office-core-wall-0',
#        'temperature': 23.078373696647592,
#        'conv_coeff': 2.257506054014824,
#        'q_hvac': -3.430135162808855,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -1690.2440709363084,
#        'heat_flux_total': -8.93393692457391}},
#      {'id': 'surf_12',
#       'properties': {'name': 'S3-office-core-wall-1',
#        'temperature': 29.845452122341445,
#        'conv_coeff': 2.6904438509655173,
#        'q_hvac': -0.18071334668527544,
#        'heat_flux_hvac': -0.0181302876396554,
#        'q_total': -171.5237968632821,
#        'heat_flux_total': -17.208334808789814}},
#      {'id': 'surf_13',
#       'properties': {'name': 'S3-office-core-wall-2',
#        'temperature': 30.054962093860176,
#        'conv_coeff': 2.667362072702451,
#        'q_hvac': -0.13888395199843673,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -127.40553325853642,
#        'heat_flux_total': -16.631863736761662}},
#      {'id': 'surf_14',
#       'properties': {'name': 'S3-office-core-wall-3',
#        'temperature': 31.23202461832324,
#        'conv_coeff': 2.660750980674676,
#        'q_hvac': -2.3922013838384855,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -2130.964822416395,
#        'heat_flux_total': -16.150398307354607}},
#      {'id': 'surf_15',
#       'properties': {'name': 'S3-office-core-wall-4',
#        'temperature': 26.991812037379688,
#        'conv_coeff': 2.947057834210076,
#        'q_hvac': -2.3206740831218333,
#        'heat_flux_hvac': -0.0181302876396554,
#        'q_total': -2763.551942740954,
#        'heat_flux_total': -21.590274995281}},
#      {'id': 'surf_16',
#       'properties': {'name': 'S4-office-core-roof',
#        'temperature': 24.551114650364127,
#        'conv_coeff': 1.4633290012945117,
#        'q_hvac': 236660.31113145404,
#        'heat_flux_hvac': 410.8512985878757,
#        'q_total': 231426.35132338718,
#        'heat_flux_total': 401.7649453517956}},
#      {'id': 'surf_17',
#       'properties': {'name': 'S4-office-core-wall-0',
#        'temperature': 23.201661786900978,
#        'conv_coeff': 2.3783196905440014,
#        'q_hvac': -3.4301351628088574,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -1858.6343495349397,
#        'heat_flux_total': -9.82397887388732}},
#      {'id': 'surf_18',
#       'properties': {'name': 'S4-office-core-wall-1',
#        'temperature': 29.713046420416283,
#        'conv_coeff': 2.772446552212156,
#        'q_hvac': -0.18071334668527247,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -195.0708409019156,
#        'heat_flux_total': -19.570720815771452}},
#      {'id': 'surf_19',
#       'properties': {'name': 'S4-office-core-wall-2',
#        'temperature': 29.83925581446098,
#        'conv_coeff': 2.7614184688780328,
#        'q_hvac': -0.13888395199843423,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -149.71142638941575,
#        'heat_flux_total': -19.543735502384063}},
#      {'id': 'surf_20',
#       'properties': {'name': 'S4-office-core-wall-3',
#        'temperature': 31.0678993773888,
#        'conv_coeff': 2.634372918981382,
#        'q_hvac': -2.392201383838492,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -2075.2832598736695,
#        'heat_flux_total': -15.728392554851732}},
#      {'id': 'surf_21',
#       'properties': {'name': 'S4-office-core-wall-4',
#        'temperature': 26.91558286783772,
#        'conv_coeff': 2.954113779167624,
#        'q_hvac': -2.3206740831218373,
#        'heat_flux_hvac': -0.018130287639655396,
#        'q_total': -2795.352027399177,
#        'heat_flux_total': -21.838713449440537}}]}},
#   {'id': 'bldg_3981208_12380',
#    'properties': {'objects': [{'id': 'surf_1',
#       'properties': {'name': 'S1-office-core-wall-0',
#        'temperature': 23.41358704219346,
#        'conv_coeff': 2.254278711963284,
#        'q_hvac': -5.639594587523645,
#        'heat_flux_hvac': -0.038540445246381304,
#        'q_total': -1552.4776659973154,
#        'heat_flux_total': -10.609482570780363}},
#      {'id': 'surf_2',
#       'properties': {'name': 'S1-office-core-wall-1',
#        'temperature': 24.030276957471386,
#        'conv_coeff': 1.9567869794455903,
#        'q_hvac': -2.514939062684545,
#        'heat_flux_hvac': -0.038540445246381304,
#        'q_total': -370.6317466001799,
#        'heat_flux_total': -5.679784750397595}},
#      {'id': 'surf_3',
#       'properties': {'name': 'S1-office-core-wall-2',
#        'temperature': 24.320905291543337,
#        'conv_coeff': 1.8568952208344316,
#        'q_hvac': -5.5963829723540215,
#        'heat_flux_hvac': -0.0385404452463813,
#        'q_total': -659.610831980495,
#        'heat_flux_total': -4.542522425546422}},
#      {'id': 'surf_4',
#       'properties': {'name': 'S1-office-core-wall-3',
#        'temperature': 25.61573890887553,
#        'conv_coeff': 2.1744760134856977,
#        'q_hvac': -2.468019312526971,
#        'heat_flux_hvac': -0.038540445246381304,
#        'q_total': -423.1212606407611,
#        'heat_flux_total': -6.6074368606168985}},
#      {'id': 'surf_5',
#       'properties': {'name': 'S2-office-core-roof',
#        'temperature': 18.921691567323503,
#        'conv_coeff': 1.6209095635463537,
#        'q_hvac': 46106.566657808144,
#        'heat_flux_hvac': 151.81080764738374,
#        'q_total': 41619.70948529143,
#        'heat_flux_total': 137.0373499702252}},
#      {'id': 'surf_6',
#       'properties': {'name': 'S2-office-core-wall-0',
#        'temperature': 23.245432342524037,
#        'conv_coeff': 2.2960691756792606,
#        'q_hvac': -5.639594587523645,
#        'heat_flux_hvac': -0.038540445246381304,
#        'q_total': -1713.7760511496324,
#        'heat_flux_total': -11.71178017122229}},
#      {'id': 'surf_7',
#       'properties': {'name': 'S2-office-core-wall-1',
#        'temperature': 23.241191436273308,
#        'conv_coeff': 1.0791657339593288,
#        'q_hvac': -2.514939062684545,
#        'heat_flux_hvac': -0.038540445246381304,
#        'q_total': -36.02067611513926,
#        'heat_flux_total': -0.5520025976578866}},
#      {'id': 'surf_8',
#       'properties': {'name': 'S2-office-core-wall-2',
#        'temperature': 23.85936255178877,
#        'conv_coeff': 1.9783773459084892,
#        'q_hvac': -5.5963829723540215,
#        'heat_flux_hvac': -0.0385404452463813,
#        'q_total': -899.797634108359,
#        'heat_flux_total': -6.196609778402941}},
#      {'id': 'surf_9',
#       'properties': {'name': 'S2-office-core-wall-3',
#        'temperature': 25.58085688134302,
#        'conv_coeff': 2.1804568144595335,
#        'q_hvac': -2.4680193125269714,
#        'heat_flux_hvac': -0.038540445246381304,
#        'q_total': -428.34089115300395,
#        'heat_flux_total': -6.688946305434598}}]}},
#   {'id': 'bldg_3981237_30681',
#    'properties': {'objects': [{'id': 'surf_1',
#       'properties': {'name': 'S1-retail-core-wall-0',
#        'temperature': 24.131216899399238,
#        'conv_coeff': 2.0952215143271427,
#        'q_hvac': -0.761986544720799,
#        'heat_flux_hvac': -0.02637317493804193,
#        'q_total': -189.92974468019023,
#        'heat_flux_total': -6.573673009178492}},
#      {'id': 'surf_2',
#       'properties': {'name': 'S1-retail-core-wall-2',
#        'temperature': 25.557995418590426,
#        'conv_coeff': 2.6236845408970133,
#        'q_hvac': -0.7463594011816492,
#        'heat_flux_hvac': -0.02637317493804193,
#        'q_total': -512.2705810958378,
#        'heat_flux_total': -18.101469117242093}},
#      {'id': 'surf_3',
#       'properties': {'name': 'S1-retail-core-wall-3',
#        'temperature': 25.568435692779126,
#        'conv_coeff': 1.7078960793175135,
#        'q_hvac': -2.4138962963766657,
#        'heat_flux_hvac': -0.026373174938041935,
#        'q_total': -245.7730998878988,
#        'heat_flux_total': -2.6852093721415544}},
#      {'id': 'surf_4',
#       'properties': {'name': 'S2-retail-core-roof',
#        'temperature': 20.3394590783462,
#        'conv_coeff': 1.5408260548540145,
#        'q_hvac': 18280.046400068706,
#        'heat_flux_hvac': 105.40065350545032,
#        'q_total': 16225.020200754258,
#        'heat_flux_total': 93.5516078499781}},
#      {'id': 'surf_5',
#       'properties': {'name': 'S2-retail-core-wall-0',
#        'temperature': 23.86708785357192,
#        'conv_coeff': 2.053903030090651,
#        'q_hvac': -0.761986544720799,
#        'heat_flux_hvac': -0.02637317493804193,
#        'q_total': -193.60146379950027,
#        'heat_flux_total': -6.700755162174249}},
#      {'id': 'surf_6',
#       'properties': {'name': 'S2-retail-core-wall-2',
#        'temperature': 24.90018173079668,
#        'conv_coeff': 2.5169582967179984,
#        'q_hvac': -0.7463594011816491,
#        'heat_flux_hvac': -0.02637317493804193,
#        'q_total': -436.3113143132573,
#        'heat_flux_total': -15.417390873100262}},
#      {'id': 'surf_7',
#       'properties': {'name': 'S2-retail-core-wall-3',
#        'temperature': 25.5011765646243,
#        'conv_coeff': 1.862276159738836,
#        'q_hvac': -2.4138962963766657,
#        'heat_flux_hvac': -0.026373174938041935,
#        'q_total': -325.47858514294927,
#        'heat_flux_total': -3.556036635644243}}]}}]}
